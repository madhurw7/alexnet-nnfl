# %%
import numpy as np
from PIL import Image

# %%
inSample1, outSample1 = applyAug(inputTrain[0], outputTrain[0])

# %%
len(inputTrain)
# Out:
# 20000

# %%
# Out:
# /Users/madhurwadhwa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: ComplexWarning: Casting complex values to real discards the imaginary part
#   app.launch_new_instance()

# %%
len(augIn[0:4])
# Out:
# 4

# %%
class TrainHelp:
    count = 0
    
    trainData = np.load('./trainDataWOAug1.npz')
    inputTrain = trainData['arr_0']
    outputTrain = trainData['arr_1']
    
    @staticmethod
    def pcaAug(original_image):
        #Takes in an image as a np array and returns the pca augmented image as a np array
        renorm_image = np.reshape(original_image,(original_image.shape[0]*original_image.shape[1],3))

        renorm_image = renorm_image.astype('float32')
        renorm_image -= np.mean(renorm_image, axis=0)
        renorm_image /= np.std(renorm_image, axis=0)

        cov = np.cov(renorm_image, rowvar=False)

        lambdas, p = np.linalg.eig(cov)
        alphas = np.random.normal(0, 0.1, 3)

        delta = np.dot(p, alphas*lambdas)

        delta = (delta).astype('int8')

        pca_color_image = np.maximum(np.minimum(original_image + delta, 255), 0).astype('uint8')
        return pca_color_image

    @staticmethod
    def randomizeOrder(inArr, outArr, n):
        idx = np.array(range(n))
        np.random.shuffle(idx)
        inList = []
        outList = []
        for i in range(n):
            inList.append(inArr[idx[i]])
            outList.append(outArr[idx[i]])
        return inList, outList


    @staticmethod
    def applyAug(img, outputOneHot):
        arr = [img[0:56, 0:56, :], img[7:, 0:56, :], img[0:56, 7:, :], img[7:, 7:, :], img[3:59, 3:59, :]]
        arr = arr + [np.flip(arr[0], 1),np.flip(arr[1], 1), np.flip(arr[2], 1), np.flip(arr[3], 1), np.flip(arr[4], 1)]
        pcaArr = []
        for i in range(len(arr)):
            pcaArr.append(TrainHelp.pcaAug(arr[i]))
        inputArr = arr + pcaArr
        outArr = []
        for i in range(len(inputArr)):
            outArr.append(outputOneHot)
        return inputArr, outArr
    
    
    @staticmethod
    def createTrainingSet():
        inputArray = []
        outputArray = []
        for i in range(len(inputTrain)):
            tempIn, tempOut = TrainHelp.applyAug(inputTrain[i], outputTrain[i])
            inputArray = inputArray + tempIn
            outputArray = outputArray + tempOut
        return TrainHelp.randomizeOrder(inputArray, outputArray, len(inputArray))
    
    augIn, augOut = TrainHelp.createTrainingSet()
    
    @staticmethod
    def getTrainingSample():
        startidx = (count*200)%400000
        endidx = ((count+1)*200)%400000
        TrainHelp.count += 1
        return augIn[startidx: endidx], augOut[startidx: endidx]

# %%
a,b = TrainHelp.getTrainingSample()

# %%
for i in range(200):
    c,d = TrainHelp.getTrainingSample()

# %%
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
